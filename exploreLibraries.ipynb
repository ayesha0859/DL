# %% [markdown]
# <a href="https://colab.research.google.com/github/ayesha0859/DL/blob/main/exploreLibraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. TensorFlow

# %%
# !pip install mxnet
# !pip install transformers

# %%
import tensorflow as tf

# simple tensor
a = tf.constant([1, 2, 3])
b = tf.constant([4, 5, 6])

# addition
c = tf.add(a, b)

print("TensorFlow Output:", c)

# %% [markdown]
# ### 2. Keras (often integrated with TensorFlow)

# %%
from tensorflow import keras
from tensorflow.keras import layers

# build model
model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=(2,)),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy')

model.summary()

# %% [markdown]
# ### 3. MXNet (Apache MXNet)

# %%
# Install MXNet if not already installed
# !pip install mxnet

# %% [markdown]
# ### 4. JAX

# %%
import jax
import jax.numpy as jnp

# Create a JAX array
x = jnp.array([1.0, 2.0, 3.0])
print(x)

# Apply a JAX transformation (e.g., JIT compilation)
@jax.jit
def sum_and_square(x):
    return jnp.sum(x ** 2)

print(sum_and_square(x))

# %% [markdown]
# ### 5. Hugging Face Transformers

# %%
# Install transformers library if not already installed
# !pip install transformers

# %%
from transformers import pipeline

# Load a sentiment analysis pipeline
sentiment_analyzer = pipeline("sentiment-analysis")

# Analyze text
result = sentiment_analyzer("I love using deep learning libraries!")
print("Hugging face output:", result)

result = sentiment_analyzer("This is a terrible movie.")
print(result)
